# %% [markdown]
# <a href="https://colab.research.google.com/github/andradedionathan-dev/aluraflix2026/blob/main/aula1_introducao_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, word! meu primeiro código no colab.")
# Out:
# hello, word! meu primeiro código no colab.

# %% [markdown]
# # Minha Primeira Aula de Python e IA
# Neste notebook, estou aprendendo a configurar o ambiente e gerenciar chaves de segurança.

# %%
from google.colab import userdata

# Busca o segredo guardado no painel da chave sem expor o texto na tela
api_key = userdata.get('GOOGLE_API_KEY')
print("Chave carregada com segurança!")
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1456/4195997470.py in <cell line: 0>()
#       2
#       3 # Busca o segredo guardado no painel da chave sem expor o texto na tela
# ----> 4 api_key = userdata.get('GOOGLE_API_KEY')
#       5 print("Chave carregada com segurança!")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GOOGLE_API_KEY does not exist.
